# %% [markdown]
# # Matplotlib

# %%
# %lsmagic # show list of magic commands
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %install_default_config  %install_ext  %install_profiles  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# ### Ploting curves with matplotlib and numpy

# %%
from IPython.core.display import HTML
src = 'http://matplotlib.org/'
HTML("<iframe src=" + src + " width=1000 height=350></iframe>")
# Out:
# <iframe src=http://matplotlib.org/ width=1000 height=350></iframe>

# %%
src = 'http://wiki.scipy.org/Tentative_NumPy_Tutorial'
HTML("<iframe src=" + src + " width=1000 height=350></iframe>")
# Out:
# <iframe src=http://wiki.scipy.org/Tentative_NumPy_Tutorial width=1000 height=350></iframe>

# %%
# This line configures matplotlib to show figures embedded in the notebook, 
# instead of opening a new window for each figure

# matplotlib-ի գրաֆիկները կգծվեն ipynb-ի մեջ եթե աշխատացնեք հետևյալ հրամանը
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
y =([1,8,4,5,3,4])
plt.plot(y)
plt.ylabel('|This is Berqarat')
plt.grid(True)
plt.show()

# %%
plt.plot([7,8,9,4,5,8,7])
plt.ylabel('Easy peasy lemons quezy')
plt.grid(True)
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,7,19])
plt.ylabel('some numbers')
plt.grid(True)
plt.xlabel('x')
plt.show()

# %%
plt.plot([1,2,3,4], [2,6,12,15], 'ro')
plt.axis([0, 6, 0, 20])
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Easy peasy lemons queezy',fontsize=65)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
t = np.arange(0., 8., 0.2)

plt.xlabel('x',fontsize=26)
plt.ylabel('y',fontsize=15)
plt.title('Testing Numpy with Matplotlib',fontsize=14)
# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**8, 'rs', t, t**6, 'k^')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
x3 = np.linspace(0.1, 9.0)

y1 = np.sin(2 * np.pi * x1) * np.exp(-x1)
y2 = np.sin(2 * np.pi * x2)
y3 = np.sin(2 * np.pi * x3)

plt.subplot(3, 1, 1)
plt.plot(x1, y1, 'go-')
plt.title('Subplots')
plt.ylabel('Damped oscillation')

plt.subplot(3, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.subplot(3, 1, 3)
plt.plot(x3, y3, 'gd')
plt.title('easy')
plt.xlabel('time (k)')
plt.ylabel('mm')

plt.show()

# %%
plt.subplot?
